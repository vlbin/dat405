# %% [markdown]
# # Assignment 1
# Group 69
# Albin Landgren (10 hours spent), Alexander Jyborn (10 hours spent)

# %% [markdown]
# ## 1a.

# %%
import pandas as pd

#Load the datasets into pandas DataFrames
life_exp = pd.read_csv('./life-expectancy.csv')
gdp = pd.read_csv('./GDP-2015.csv')

#Select life expectancy data from year 2015 and merge with gdp dataset
common = life_exp[life_exp['Year'] == 2015].merge(gdp, on=['Code'])

#Plot the data
plot = common.plot.scatter(x = 'GDP per capita', y='Life expectancy (years)', c='DarkBlue')

# %% [markdown]
# ## 1b.
# The results we obtained seem resonable, compared to graphs found online it looks similar. The results are also resonable because countries with a lower GDP,
# probably means that the country cant allocate enough reserouces into healthcare forexample because it is to expensive. And thus people having a lower life expectancy.

# %% [markdown]
# ## 1c.
# Since the GDP dataset provided information for the year 2015, we extracted the datapoints from 2015 from the life expectancy dataset.
# We merged the two datasets based on the ISO code for the country, thus leaving out non-country regions and countries that did not exist in both of the datasets.
#
# ## 1d.

# %%
import pandas as pd

#Load the datasets into pandas DataFrames
life_exp = pd.read_csv('./life-expectancy.csv')
gdp = pd.read_csv('./GDP-2015.csv')

#Select life expectancy data from year 2015 and merge with gdp dataset
common = life_exp[life_exp['Year'] == 2015].merge(gdp, on=['Code', 'Entity', 'Year'])

mean = common['Life expectancy (years)'].mean()
std = common['Life expectancy (years)'].std()

higher = common[common['Life expectancy (years)'] > mean + std]

gdp_mean = common['GDP per capita'].mean()
le_mean = common['Life expectancy (years)'].mean()

higher.head(165)
# Out:
#              Entity Code  Year  Life expectancy (years)  GDP per capita
# 6         Australia  AUS  2015                   82.794           44336
# 7           Austria  AUT  2015                   81.182           44845
# 13          Belgium  BEL  2015                   80.969           39531
# 24           Canada  CAN  2015                   82.026           42844
# 37           Cyprus  CYP  2015                   80.350           25903
# 40          Denmark  DNK  2015                   80.475           44939
# 50          Finland  FIN  2015                   81.196           37920
# 51           France  FRA  2015                   82.224           38448
# 55          Germany  DEU  2015                   80.770           46426
# 57           Greece  GRC  2015                   81.548           24545
# 63        Hong Kong  HKG  2015                   84.043           46504
# 65          Iceland  ISL  2015                   82.481           40572
# 70          Ireland  IRL  2015                   81.344           53372
# 71           Israel  ISR  2015                   82.340           31729
# 72            Italy  ITA  2015                   82.828           34673
# 74            Japan  JPN  2015                   83.879           36030
# 87       Luxembourg  LUX  2015                   81.636           67804
# 93            Malta  MLT  2015                   81.896           26577
# 105     Netherlands  NLD  2015                   81.715           48463
# 106     New Zealand  NZL  2015                   81.713           33445
# 111          Norway  NOR  2015                   81.912           76305
# 120        Portugal  PRT  2015                   81.224           27255
# 133       Singapore  SGP  2015                   82.877           67110
# 135        Slovenia  SVN  2015                   80.673           28077
# 137     South Korea  KOR  2015                   82.100           35316
# 138           Spain  ESP  2015                   82.981           33376
# 142          Sweden  SWE  2015                   82.251           43464
# 143     Switzerland  CHE  2015                   83.142           61476
# 157  United Kingdom  GBR  2015                   81.052           38749

# %% [markdown]
# ## 1e.
# We define high/low as above/below the mean value.

# %% [markdown]
# **Mean life expectancy and GDP per capita**:

# %%
print(f'Life expectancy: {round(le_mean, 1)} years')
print(f'GDP per capita: {round(gdp_mean, 1)} USD')
# Out:
# Life expectancy: 71.9 years
# GDP per capita: 18149.5 USD

# %%
import pandas as pd

#Load the datasets into pandas DataFrames
life_exp = pd.read_csv('./life-expectancy.csv')
gdp = pd.read_csv('./GDP-2015.csv')

#Select life expectancy data from year 2015 and merge with gdp dataset
common = life_exp[life_exp['Year'] == 2015].merge(gdp, on=['Code', 'Entity', 'Year'])

low_gdp = common[common['GDP per capita'] < gdp_mean]
high_le = low_gdp[low_gdp['Life expectancy (years)'] > le_mean]

high_le.head(165)
# Out:
#                      Entity Code  Year  Life expectancy (years)  \
# 1                   Albania  ALB  2015                   78.025
# 2                   Algeria  DZA  2015                   76.090
# 5                   Armenia  ARM  2015                   74.467
# 8                Azerbaijan  AZE  2015                   72.266
# 11                 Barbados  BRB  2015                   78.801
# 16   Bosnia and Herzegovina  BIH  2015                   76.865
# 18                   Brazil  BRA  2015                   74.994
# 19                 Bulgaria  BGR  2015                   74.584
# 25               Cape Verde  CPV  2015                   72.117
# 29                    China  CHN  2015                   75.928
# 30                 Colombia  COL  2015                   76.531
# 33               Costa Rica  CRI  2015                   79.565
# 36                     Cuba  CUB  2015                   78.561
# 42                 Dominica  DMA  2015                   74.194
# 43       Dominican Republic  DOM  2015                   73.241
# 44                  Ecuador  ECU  2015                   76.143
# 46              El Salvador  SLV  2015                   72.412
# 54                  Georgia  GEO  2015                   72.973
# 58                Guatemala  GTM  2015                   73.250
# 62                 Honduras  HND  2015                   74.495
# 68                     Iran  IRN  2015                   75.796
# 73                  Jamaica  JAM  2015                   74.098
# 75                   Jordan  JOR  2015                   74.078
# 82                  Lebanon  LBN  2015                   78.768
# 85                    Libya  LBY  2015                   72.121
# 88                Macedonia  MKD  2015                   75.406
# 96                   Mexico  MEX  2015                   74.904
# 99               Montenegro  MNE  2015                   76.452
# 100                 Morocco  MAR  2015                   75.726
# 107               Nicaragua  NIC  2015                   73.649
# 114               Palestine  PSE  2015                   73.442
# 116                Paraguay  PRY  2015                   73.662
# 117                    Peru  PER  2015                   75.792
# 126             Saint Lucia  LCA  2015                   75.596
# 130                  Serbia  SRB  2015                   75.309
# 139               Sri Lanka  LKA  2015                   76.316
# 148                Thailand  THA  2015                   76.091
# 151                 Tunisia  TUN  2015                   75.922
# 161               Venezuela  VEN  2015                   72.584
# 162                 Vietnam  VNM  2015                   75.110
#
#      GDP per capita
# 1             10947
# 2             13024
# 5              9552
# 8             16045
# 11            10030
# 16            10305
# 18            15377
# 19            17254
# 25             6358
# 29            12002
# 30            12858
# 33            13568
# 36             7889
# 42             9537
# 43            13382
# 44            10914
# 46             8163
# 54            10198
# 58             7055
# 62             4352
# 68            15039
# 73             7115
# 75            11738
# 82            12665
# 85             8514
# 88            13586
# 96            15766
# 99            17738
# 100            7577
# 107            4699
# 114            4422
# 116            8364
# 117           11215
# 126           10687
# 130           13556
# 139           10734
# 148           13938
# 151           10608
# 161           16257
# 162            5733

# %% [markdown]
# ## 1f.
# We can test this assumption by using the reverse logic of the previous question, querying the
# datasets for countries with above mean GDP and below mean life expectancy and seeing if this yields any results.
#
# We define high/low as above/below the mean value.

# %%
import pandas as pd

#Load the datasets into pandas DataFrames
life_exp = pd.read_csv('./life-expectancy.csv')
gdp = pd.read_csv('./GDP-2015.csv')

#Select life expectancy data from year 2015 and merge with gdp dataset
common = life_exp[life_exp['Year'] == 2015].merge(gdp, on=['Code', 'Entity', 'Year'])

gdp_mean = common['GDP per capita'].mean()
le_mean = common['Life expectancy (years)'].mean()

high_gdp = common[common['GDP per capita'] > gdp_mean]
low_le = high_gdp[high_gdp['Life expectancy (years)'] < le_mean]

# %%
low_le.head(165)
# Out:
#                 Entity Code  Year  Life expectancy (years)  GDP per capita
# 47   Equatorial Guinea  GNQ  2015                   57.359           35743
# 76          Kazakhstan  KAZ  2015                   71.319           23408
# 124             Russia  RUS  2015                   71.464           23118
# 153       Turkmenistan  TKM  2015                   67.704           21262

# %% [markdown]
# It does not seem like every strong economy (when indicated by GDP per capita) has a high life expectancy,
# for example Equatorial Guinea from the results above has a life expectancy of 57.3 years which is well
# below the mean of 71.9 years.
#
# ## 1g.
# If we use GDP per capita as the sole indicator of a strong economy we will see countries with massive natural resources
# at the top even though a large portion of the country lives in poverty, for example. We can back this claim by looking at
# Equatorial Guinea which, even though it has a high GDP per capita, 70% of the population lives in poverty, according to
# [this 2009 report](https://europa.eu/capacity4dev/file/13439/download?token=vGaigiBp) from the Overseas Development Institute.
# The reason behind the high GDP of Equatorial Guinea is mainly its [oil resources](https://www.hrw.org/news/2017/01/27/equatorial-guinea-why-poverty-plagues-high-income-nation),
# according to Human Rights Watch, and according to that article, the poverty can be explained by
# "the vast personal fortunes that senior government officials have amassed during the oil boom and because of how the country invests–or doesn't invest–in itself".
#
# Sources:
# * https://europa.eu/capacity4dev/file/13439/download?token=vGaigiBp
# * https://www.hrw.org/news/2017/01/27/equatorial-guinea-why-poverty-plagues-high-income-nation

# %% [markdown]
# ## 2a. discuss why we chose this data and motivate our choice of visualization
#
# **What data did we choose?**
# We chose a dataset from Our World in Data representing the:
# > "Share of persons of working age who were engaged in any activity to produce goods or provide services for pay or
# profit in the agriculture sector (agriculture, hunting, forestry and fishing)." [Source](https://ourworldindata.org/grapher/share-of-the-labor-force-employed-in-agriculture)
#
# We also chose a dataset from the same source representing life satisfaction and the life expectancy dataset provided in
# the course material to see if any correlation could be found between these factors.
#
# Our World in Data defines the data surrounding life satisfaction as follows:
# > "Life satisfaction is self-reported as the answer to the following question: 'Please imagine a ladder, with steps
# numbered from 0 at the bottom to 10 at the top. The top of the ladder represents the best possible life for you and the
# bottom of the ladder represents the worst possible life for you. On which step of the ladder would you say you
# personally feel you stand at this time?'" [Source](https://ourworldindata.org/grapher/happiness-cantril-ladder?time=2015)
#
# We chose data from 2015 to get a wide perspective as most countries had data from this year.
#
# **Questions to answer from this data:**
# * Does the percentage of population in agriculture correlate in anyway with the life satisfaction of the population?
# * Are there any outliers - if so, how could these be explained?
#
# **Why did we choose this type of visualization for the data?**
# The scatter plots gives us a general oversight of if life satisfaction/expectancy and agriculture correlate, and if so, how.
# We used tables to get the outliers from these sets so we can identify them and try to analyze why these countries are not following the trend. And hopefully see
# what other factors are affecting them.
#
#
# Sources:
#
# * https://ourworldindata.org/grapher/share-of-the-labor-force-employed-in-agriculture
# * https://ourworldindata.org/grapher/happiness-cantril-ladder?time=2015

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Load the datasets into pandas DataFrames
life_satisfaction = pd.read_csv('./life_satisfaction.csv')
agriculture = pd.read_csv('./agriculture_employment.csv')
gdp = pd.read_csv('./GDP-2015.csv')
continents = pd.read_csv('./countries_continents.csv')

life_satisfaction = life_satisfaction[life_satisfaction['Year'] == 2015]
life_satisfaction = life_satisfaction.rename(columns = {list(life_satisfaction)[-1]: 'Satisfaction'})

agriculture = agriculture[agriculture['Year'] == 2015]
agriculture = agriculture.rename(columns = {list(agriculture)[-1]: 'Agriculture'})

agr_sat = pd.merge(life_satisfaction, agriculture, on=['Code', 'Entity', 'Year'])
combined = pd.merge(agr_sat, continents[['Continent_Name', 'Three_Letter_Country_Code']], left_on='Code', right_on='Three_Letter_Country_Code')
combined = combined.drop('Three_Letter_Country_Code', 1)
combined = pd.merge(combined, gdp, on=['Code', 'Entity', 'Year'])

colors = {'Europe':'cornflowerblue', 'Africa': 'limegreen', 'North America': 'red', 'South America': 'darkblue', 'Asia': 'orchid', 'Oceania': 'orange'}

sat_mean = combined['Satisfaction'].mean()
agr_mean = combined['Agriculture'].mean()

high_agr = combined[combined['Agriculture'] > agr_mean]
low_agr = combined[combined['Agriculture'] < agr_mean]

low_agr_low_sat = low_agr[low_agr['Satisfaction'] < sat_mean]
high_agr_high_sat = high_agr[high_agr['Satisfaction'] > sat_mean]

grouped = combined.groupby('Continent_Name')

# %% [markdown]
# **Plot: Life satisfaction as a function of agriculture employment share**

# %%
fig, ax = plt.subplots()

for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='Agriculture', y='Satisfaction', label=key, color=colors[key])


plt.show()

# %% [markdown]
# **Countries with low life satisfaction & low agriculture employment**

# %%
low_agr_low_sat.head(250)
# Out:
#                      Entity Code  Year  Satisfaction  Agriculture  \
# 15   Bosnia and Herzegovina  BIH  2015      5.117178    17.875999
# 18                 Bulgaria  BGR  2015      4.865401     6.856000
# 25                    China  CHN  2015      5.303878    19.548000
# 30                  Croatia  HRV  2015      5.205438     9.228000
# 35       Dominican Republic  DOM  2015      5.061862    13.309000
# 53                  Hungary  HUN  2015      5.344383     4.900000
# 57                     Iran  IRN  2015      4.749956    18.032000
# 58                     Iraq  IRQ  2015      4.493377    20.302999
# 63                   Jordan  JOR  2015      5.404593     3.671000
# 70                  Lebanon  LBN  2015      5.171971     3.220000
# 84               Montenegro  MNE  2015      5.124921     7.766000
# 96                Palestine  PSE  2015      4.695239     8.650000
# 102                Portugal  PRT  2015      5.080866     7.530000
# 110                  Serbia  SRB  2015      5.317685    19.459000
# 115            South Africa  ZAF  2015      4.887326     5.613000
# 125                 Tunisia  TUN  2015      5.131612    13.203000
# 130                 Ukraine  UKR  2015      3.964543    15.257000
#
#     Continent_Name  GDP per capita
# 15          Europe           10305
# 18          Europe           17254
# 25            Asia           12002
# 30          Europe           20905
# 35   North America           13382
# 53          Europe           23539
# 57            Asia           15039
# 58            Asia           13087
# 63            Asia           11738
# 70            Asia           12665
# 84          Europe           17738
# 96            Asia            4422
# 102         Europe           27255
# 110         Europe           13556
# 115         Africa           12054
# 125         Africa           10608
# 130         Europe            9429

# %% [markdown]
# **Countries with high life satisfaction & high agriculture employment**

# %%
high_agr_high_sat.head(250)
# Out:
#           Entity Code  Year  Satisfaction  Agriculture Continent_Name  \
# 14       Bolivia  BOL  2015      5.834329    27.848000  South America
# 36       Ecuador  ECU  2015      5.964075    26.191999  South America
# 49     Guatemala  GTM  2015      6.464987    31.875999  North America
# 82       Moldova  MDA  2015      6.017472    34.151001         Europe
# 91     Nicaragua  NIC  2015      5.924113    30.681999  North America
# 99          Peru  PER  2015      5.577263    28.261999  South America
# 100  Philippines  PHL  2015      5.547489    29.152000           Asia
# 104      Romania  ROU  2015      5.777491    25.586000         Europe
# 123     Thailand  THA  2015      6.201763    32.280998           Asia
#
#      GDP per capita
# 14             5969
# 36            10914
# 49             7055
# 82             5569
# 91             4699
# 99            11215
# 100            6870
# 104           20549
# 123           13938

# %% [markdown]
# ## 2b: discuss and analyze our results
#
# **Does the percentage of population in agriculture correlate in anyway with the life satisfaction of the population?**
# Yes there seems to be some correlation between percentage of population in agriculture and the populations life satisfaction, which can be seen in the first
# graph. Countries with a high percentage of agriculture employment generally have a lower satisfaction in life. This, however, does not imply that there is causation
# between the two metrics. When observing the results one can see that many of the countries with high agricultural employment
# and low life satisfaction are African countries, where extreme poverty in 2015 was [four times higher](https://www.worldbank.org/en/region/afr/publication/accelerating-poverty-reduction-in-africa-in-five-charts)
# than the [world at large](https://www.worldbank.org/en/topic/poverty/overview).
# This factor could indicate that the employment share in agriculture is due to a lack of other opportunities, and that
# *this* is the reason for the low life satisfaction, not the high agricultural employment itself.
#
# Sources:
# * https://www.worldbank.org/en/region/afr/publication/accelerating-poverty-reduction-in-africa-in-five-charts
# * https://www.worldbank.org/en/topic/poverty/overview
#
#
# **Are there any outliers - if so, how could these be explained?**
# For example, Lebanon that can be seen in the low agriculture and low satisfaction table, this can most likely be explained by different factors. In Lebanons case a
# big factor for why the country has low agriculture is that it is a very small country by area and a lot of it is urbanised so there is no space for big fields.
# The low life satisfaction of countries can most likely be explained by many other factors like a corrupt goverment, economic downturn, unemployment, war or inequality.
# In Lebanons case some major factors might be a corrupt goverment and that the country is sharing a very tense border with Syria which makes a lot of the population feeling uneasy about
# a war breaking out. [Lebanon on the brink](https://www.ft.com/content/66d483fe-dbbd-11e3-b112-00144feabdc0)
# Countries with high life satisfaction aswell as high percentage of population agriculture employment exist but not a lot of them. For example Thailand has above the
# mean in both factors. However the population in agriculture is still lower than some of the really poor countries. The high life satisfaction can be explained by a lot
# of other factors like good health care, freedom, culture. In Thailands case it is most likely because of culture and religion which is very important to the population and teaches
# them to be satisfied with what they have, they also have a pretty good social security network with lets all people get access to healthcare. [Thailands Life Satisfaction and Happiness](http://www.npithailand.com/sites/default/files/Thailand%20Life%20Satisfaction%20and%20Happiness.pdf)
#
# Sources:
# * https://www.ft.com/content/66d483fe-dbbd-11e3-b112-00144feabdc0
# * http://www.npithailand.com/sites/default/files/Thailand%20Life%20Satisfaction%20and%20Happiness.pdf
